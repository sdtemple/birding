# %%
import os
import IPython.display as ipd

# %%
# Set up the folder
idx1 = 10
idx2 = 15
folder = '/mnt/d/acoustics-data/ff1010bird_wav/wav/'

# Save the files in folder
files = os.listdir(folder)
print(files[idx1:idx2])
# Out:
# ['100278.wav', '100279.wav', '100301.wav', '100302.wav', '100388.wav']

# %%
# Set up the file
idx = 200
file = files[idx]

# Make recording playable
ipd.Audio(folder + file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
